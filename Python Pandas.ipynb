# %% [markdown]
# # Python Pandas

# %% [markdown]
# ### Basics of Pandas

# %%
from urllib.request import urlretrieve

# %%
urlretrieve("https://s3.amazonaws.com/assets.datacamp.com/production/course_1606/datasets/winequality-red.csv", "winequality-red.csv")
# Out:
# ('winequality-red.csv', <http.client.HTTPMessage at 0x1e032d7d8a0>)

# %%
import pandas as pd

# %%
wine_df = pd.read_csv("winequality-red.csv", sep=";")

# %%
type(wine_df)
# Out:
# pandas.core.frame.DataFrame

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
wine_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
wine_df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
wine_df.shape
# Out:
# (1599, 12)

# %%
wine_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# ### Retrieving data from DataFrame

# %%
wine_df['quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
type(wine_df['quality'])
# Out:
# pandas.core.series.Series

# %%
wine_df['quality'][2]
# Out:
# 5

# %%
wine_df[['quality', 'alcohol']]
# Out:
#       quality  alcohol
# 0           5      9.4
# 1           5      9.8
# 2           5      9.8
# 3           6      9.8
# 4           5      9.4
# ...       ...      ...
# 1594        5     10.5
# 1595        6     11.2
# 1596        6     11.0
# 1597        5     10.2
# 1598        6     11.0
#
# [1599 rows x 2 columns]

# %%
wine_df.at[2, 'quality']
# Out:
# 5

# %%
wine_df.quality
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
# this subset also points to same DF,so making change in subset will also change value in real DF
wine_df_subset = wine_df[['quality','alcohol']]

# %%
wine_df_subset
# Out:
#       quality  alcohol
# 0           5      9.4
# 1           5      9.8
# 2           5      9.8
# 3           6      9.8
# 4           5      9.4
# ...       ...      ...
# 1594        5     10.5
# 1595        6     11.2
# 1596        6     11.0
# 1597        5     10.2
# 1598        6     11.0
#
# [1599 rows x 2 columns]

# %%
# copy method makes actual copy
wine_df_copy = wine_df.copy()

# %%
wine_df_copy
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#accessing rows using loc method
wine_df.loc[1594]
# Out:
# fixed acidity            6.2000
# volatile acidity         0.6000
# citric acid              0.0800
# residual sugar           2.0000
# chlorides                0.0900
# free sulfur dioxide     32.0000
# total sulfur dioxide    44.0000
# density                  0.9949
# pH                       3.4500
# sulphates                0.5800
# alcohol                 10.5000
# quality                  5.0000
# Name: 1594, dtype: float64

# %%
type(wine_df.loc[1594])
# Out:
# pandas.core.series.Series

# %%
#getting first n rows
wine_df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# getting last n rows
wine_df.tail(3)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6

# %%
# finding first valid(not nan) index in column
wine_df.quality.first_valid_index()
# Out:
# 0

# %%
wine_df.loc[3:8]
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# ...

# %%
# get random sample of data by rows
wine_df.sample(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1158            6.7              0.41         0.43             2.8      0.076
# 796             8.7              0.46         0.31             2.5      0.126
# 1186            6.6              0.80         0.03             7.8      0.079
# 1122            6.3              0.47         0.00             1.4      0.055
# 821             4.9              0.42         0.00             2.1      0.048
# 626             8.8              0.60         0.29             2.2      0.098
# 596            12.4              0.40         0.51             2.0      0.059
# 983             9.1              0.50         0.30             1.9      0.065
# 87              7.7              0.49         0.26             1.9      0.062
# 680            13.3              0.43         0.58             1.9      0.070
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# ### Operations of data

# %%
total_sugar = wine_df['residual sugar'].sum()

# %%
total_sugar
# Out:
# 4059.55

# %%
avg_sugar = wine_df['residual sugar'].mean()

# %%
avg_sugar
# Out:
# 2.53880550343965

# %%
total_items = wine_df['residual sugar'].count()

# %%
total_items
# Out:
# 1599

# %% [markdown]
# ### Querying & sorting rows

# %%
high_quality_wines = wine_df['quality'] > 7

# %%
high_quality_wines
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Name: quality, Length: 1599, dtype: bool

# %%
wine_df[high_quality_wines]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267             7.9              0.35         0.46             3.6      0.078
# 278            10.3              0.32         0.45             6.4      0.073
# 390             5.6              0.85         0.05             1.4      0.045
# 440            12.6              0.31         0.72             2.2      0.072
# 455            11.3              0.62         0.67             5.2      0.086
# 481             9.4              0.30         0.56             2.8      0.080
# 495            10.7              0.35         0.53             2.6      0.070
# 498            10.7              0.35         0.53             2.6      0.070
# 588             5.0              0.42         0.24             2.0      0.060
# 828             7.8              0.57         0.09             2.3      0.065
# 1061            9.1              0.40         0.50             1.8      0.071
# ...

# %%
high_sulphur_wines = wine_df[wine_df['free sulfur dioxide'] > 50]

# %%
high_sulphur_wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 14              8.9             0.620         0.18             3.8      0.176
# 15              8.9             0.620         0.19             3.9      0.170
# 396             6.6             0.735         0.02             7.9      0.122
# 400             6.6             0.735         0.02             7.9      0.122
# 584            11.8             0.330         0.49             3.4      0.093
# 925             8.6             0.220         0.36             1.9      0.064
# 926             9.4             0.240         0.33             2.3      0.061
# 982             7.3             0.520         0.32             2.1      0.070
# 1131            5.9             0.190         0.21             1.7      0.045
# 1244            5.9             0.290         0.25            13.4      0.067
# 1295            6.6             0.630         0.00             4.3      0.093
# ...

# %%
from IPython.display import display
with pd.option_context('display.min_rows', 15, 'display.max_columns', 4):
    display(wine_df)
# Out:
#       fixed acidity  volatile acidity  ...  alcohol  quality
# 0               7.4             0.700  ...      9.4        5
# 1               7.8             0.880  ...      9.8        5
# 2               7.8             0.760  ...      9.8        5
# 3              11.2             0.280  ...      9.8        6
# 4               7.4             0.700  ...      9.4        5
# 5               7.4             0.660  ...      9.4        5
# 6               7.9             0.600  ...      9.4        5
# ...             ...               ...  ...      ...      ...
# 1592            6.3             0.510  ...     11.0        6
# 1593            6.8             0.620  ...      9.5        6
# 1594            6.2             0.600  ...     10.5        5
# 1595            5.9             0.550  ...     11.2        6
# 1596            6.3             0.510  ...     11.0        6
# 1597            5.9             0.645  ...     10.2        5
# ...

# %%
free_sulphur_ratio_threshold = 0.4

# %%
high_free_sulphur_ratio = wine_df[wine_df['free sulfur dioxide'] / wine_df['total sulfur dioxide'] > free_sulphur_ratio_threshold]

# %%
high_free_sulphur_ratio
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 7               7.3             0.650         0.00             1.2      0.065
# 8               7.8             0.580         0.02             2.0      0.073
# 20              8.9             0.220         0.48             1.8      0.077
# 24              6.9             0.400         0.14             2.4      0.085
# 25              6.3             0.390         0.16             1.4      0.080
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df['free sulfur dioxide'].max()
# Out:
# 72.0

# %%
wine_df['free sulfur dioxide'] / wine_df['total sulfur dioxide']
# Out:
# 0       0.323529
# 1       0.373134
# 2       0.277778
# 3       0.283333
# 4       0.323529
#           ...
# 1594    0.727273
# 1595    0.764706
# 1596    0.725000
# 1597    0.727273
# 1598    0.428571
# Length: 1599, dtype: float64

# %%
wine_df['free sulphur ratio'] = wine_df['free sulfur dioxide'] / wine_df['total sulfur dioxide']

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.drop(['free sulphur ratio'], inplace=True, axis=1)

# %%
wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_df.sort_values('alcohol', ascending=False).head(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 652            15.9              0.36         0.65             7.5      0.096
# 588             5.0              0.42         0.24             2.0      0.060
# 142             5.2              0.34         0.00             1.8      0.050
# 144             5.2              0.34         0.00             1.8      0.050
# 1270            5.0              0.38         0.01             1.6      0.048
# 1269            5.5              0.49         0.03             1.8      0.044
# 467             8.8              0.46         0.45             2.6      0.065
# 821             4.9              0.42         0.00             2.1      0.048
# 1114            5.0              0.40         0.50             4.3      0.046
# 1228            5.1              0.42         0.00             1.8      0.044
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
wine_df.sort_values(['quality', 'alcohol'], ascending=[True, False]).head(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 899             8.3             1.020         0.02            3.40      0.084
# 1299            7.6             1.580         0.00            2.10      0.137
# 690             7.4             1.185         0.00            4.25      0.097
# 1478            7.1             0.875         0.05            5.70      0.082
# 1505            6.7             0.760         0.02            1.80      0.078
# 832            10.4             0.440         0.42            1.50      0.145
# 1374            6.8             0.815         0.00            1.20      0.267
# 1469            7.3             0.980         0.05            2.10      0.061
# 459            11.6             0.580         0.66            2.20      0.074
# 517            10.4             0.610         0.49            2.10      0.200
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
wine_df.at[899,'volatile acidity'] = 1.021

# %%
wine_df.at[899,'volatile acidity']
# Out:
# 1.021

# %%
import urllib.request

def download_url(url, save_path):
    with urllib.request.urlopen(url) as dl_file:
        with open(save_path, 'wb') as out_file:
            out_file.write(dl_file.read())

download_url('https://www.kaggle.com/datasets/shrikrishnaparab/fifa-world-cup-2022-qatar-match-data/download?datasetVersionNumber=1','./testdata/fifawc22.zip')

# %%
from zipfile import ZipFile
with ZipFile('./testdata/fifawc22.zip', 'w') as zipObj:
   # Extract all the contents of zip file in current directory
   zipObj.extractall('./testdata')

# %%
import os
os.listdir('./testdata')
# Out:
# ['bank1.txt',
#  'banknewdata.txt',
#  'fifawc22.zip',
#  'Fifa_WC_2022_Match_data.csv',
#  'results']

# %%
testdata_files = os.listdir('./testdata')
csv_filename = ''
for i in testdata_files:
    ext = os.path.splitext(i)[1]
    if ext == '.csv':
        csv_filename = i
        break
print(csv_filename)
# Out:
# Fifa_WC_2022_Match_data.csv

# %%
fifa_df = pd.read_csv('./testdata/'+csv_filename, sep=',', encoding='latin-1')

# %%
fifa_df
# Out:
#     match_no day_of_week       date   hour                          venue  \
# 0          1         Sun  20-Nov-22  17:00                Al Bayt Stadium
# 1          2         Mon  21-Nov-22  14:00  Khalifa International Stadium
# 2          3         Mon  21-Nov-22  17:00             Al Thumama Stadium
# 3          4         Mon  21-Nov-22  20:00          Ahmed bin Ali Stadium
# 4          5         Tue  22-Nov-22  11:00          Lusail Iconic Stadium
# 5          6         Tue  22-Nov-22  14:00         Education City Stadium
# 6          7         Tue  22-Nov-22  17:00                    Stadium 974
# 7          8         Tue  22-Nov-22  20:00              Al Janoub Stadium
# 8          9         Wed  23-Nov-22  11:00                Al Bayt Stadium
# 9         10         Wed  23-Nov-22  14:00  Khalifa International Stadium
# 10        11         Wed  23-Nov-22  17:00             Al Thumama Stadium
# 11        12         Wed  23-Nov-22  20:00          Ahmed bin Ali Stadium
# ...

# %% [markdown]
# ### Datetime

# %%
fifa_df.date
# Out:
# 0     20-Nov-22
# 1     21-Nov-22
# 2     21-Nov-22
# 3     21-Nov-22
# 4     22-Nov-22
# 5     22-Nov-22
# 6     22-Nov-22
# 7     22-Nov-22
# 8     23-Nov-22
# 9     23-Nov-22
# 10    23-Nov-22
# 11    23-Nov-22
# 12    24-Nov-22
# 13    24-Nov-22
# 14    24-Nov-22
# 15    24-Nov-22
# 16    25-Nov-22
# 17    25-Nov-22
# 18    25-Nov-22
# 19    25-Nov-22
# 20    26-Nov-22
# 21    26-Nov-22
# 22    26-Nov-22
# 23    26-Nov-22
# 24    27-Nov-22
# 25    27-Nov-22
# 26    27-Nov-22
# 27    27-Nov-22
# 28    28-Nov-22
# 29    28-Nov-22
# 30    28-Nov-22
# 31    28-Nov-22
# 32    29-Nov-22
# 33    29-Nov-22
# 34    29-Nov-22
# 35    29-Nov-22
# 36    30-Nov-22
# 37    30-Nov-22
# 38    30-Nov-22
# 39    30-Nov-22
# 40     1-Dec-22
# 41     1-Dec-22
# 42     1-Dec-22
# 43     1-Dec-22
# 44     2-Dec-22
# 45     2-Dec-22
# 46     2-Dec-22
# 47     2-Dec-22
# 48     3-Dec-22
# 49     3-Dec-22
# 50     4-Dec-22
# 51     4-Dec-22
# 52     5-Dec-22
# 53     5-Dec-22
# 54     6-Dec-22
# ...

# %%
fifa_df['date'] = pd.to_datetime(fifa_df['date'])

# %%
fifa_df['date']
# Out:
# 0    2022-11-20
# 1    2022-11-21
# 2    2022-11-21
# 3    2022-11-21
# 4    2022-11-22
# 5    2022-11-22
# 6    2022-11-22
# 7    2022-11-22
# 8    2022-11-23
# 9    2022-11-23
# 10   2022-11-23
# 11   2022-11-23
# 12   2022-11-24
# 13   2022-11-24
# 14   2022-11-24
# 15   2022-11-24
# 16   2022-11-25
# 17   2022-11-25
# 18   2022-11-25
# 19   2022-11-25
# 20   2022-11-26
# 21   2022-11-26
# 22   2022-11-26
# 23   2022-11-26
# 24   2022-11-27
# 25   2022-11-27
# 26   2022-11-27
# 27   2022-11-27
# 28   2022-11-28
# 29   2022-11-28
# 30   2022-11-28
# 31   2022-11-28
# 32   2022-11-29
# 33   2022-11-29
# 34   2022-11-29
# 35   2022-11-29
# 36   2022-11-30
# 37   2022-11-30
# 38   2022-11-30
# 39   2022-11-30
# 40   2022-12-01
# 41   2022-12-01
# 42   2022-12-01
# 43   2022-12-01
# 44   2022-12-02
# 45   2022-12-02
# 46   2022-12-02
# 47   2022-12-02
# 48   2022-12-03
# 49   2022-12-03
# 50   2022-12-04
# 51   2022-12-04
# 52   2022-12-05
# 53   2022-12-05
# 54   2022-12-06
# ...

# %%
fifa_df['year'] = fifa_df['date'].dt.year

# %%
fifa_df
# Out:
#     match_no day_of_week       date   hour                          venue  \
# 0          1         Sun 2022-11-20  17:00                Al Bayt Stadium
# 1          2         Mon 2022-11-21  14:00  Khalifa International Stadium
# 2          3         Mon 2022-11-21  17:00             Al Thumama Stadium
# 3          4         Mon 2022-11-21  20:00          Ahmed bin Ali Stadium
# 4          5         Tue 2022-11-22  11:00          Lusail Iconic Stadium
# 5          6         Tue 2022-11-22  14:00         Education City Stadium
# 6          7         Tue 2022-11-22  17:00                    Stadium 974
# 7          8         Tue 2022-11-22  20:00              Al Janoub Stadium
# 8          9         Wed 2022-11-23  11:00                Al Bayt Stadium
# 9         10         Wed 2022-11-23  14:00  Khalifa International Stadium
# 10        11         Wed 2022-11-23  17:00             Al Thumama Stadium
# 11        12         Wed 2022-11-23  20:00          Ahmed bin Ali Stadium
# ...

# %%
fifa_df['month'] = pd.DatetimeIndex(fifa_df['date']).month
fifa_df['day'] = pd.DatetimeIndex(fifa_df['date']).day
fifa_df['weekday'] = pd.DatetimeIndex(fifa_df['date']).weekday

# %%
fifa_df[['day','month','year','weekday']]
# Out:
#     day  month  year  weekday
# 0    20     11  2022        6
# 1    21     11  2022        0
# 2    21     11  2022        0
# 3    21     11  2022        0
# 4    22     11  2022        1
# 5    22     11  2022        1
# 6    22     11  2022        1
# 7    22     11  2022        1
# 8    23     11  2022        2
# 9    23     11  2022        2
# 10   23     11  2022        2
# 11   23     11  2022        2
# 12   24     11  2022        3
# 13   24     11  2022        3
# 14   24     11  2022        3
# 15   24     11  2022        3
# 16   25     11  2022        4
# 17   25     11  2022        4
# 18   25     11  2022        4
# 19   25     11  2022        4
# 20   26     11  2022        5
# 21   26     11  2022        5
# 22   26     11  2022        5
# 23   26     11  2022        5
# 24   27     11  2022        6
# 25   27     11  2022        6
# 26   27     11  2022        6
# 27   27     11  2022        6
# 28   28     11  2022        0
# 29   28     11  2022        0
# ...

# %%
fifa_df['total_goals'] = fifa_df['1_goals'] + fifa_df['2_goals']

# %%
fifa_df['total_goals']
# Out:
# 0     2
# 1     8
# 2     2
# 3     2
# 4     3
# 5     0
# 6     0
# 7     5
# 8     0
# 9     3
# 10    7
# 11    1
# 12    1
# 13    0
# 14    5
# 15    2
# 16    2
# 17    4
# 18    2
# 19    0
# 20    1
# 21    2
# 22    3
# 23    2
# 24    1
# 25    2
# 26    5
# 27    2
# 28    6
# 29    5
# 30    1
# 31    2
# 32    2
# 33    3
# 34    3
# 35    1
# 36    1
# 37    1
# 38    2
# 39    3
# 40    0
# 41    3
# 42    3
# 43    6
# 44    2
# 45    3
# 46    5
# 47    1
# 48    4
# 49    3
# 50    4
# 51    3
# 52    2
# 53    5
# 54    0
# 55    7
# 56    2
# 57    4
# 58    1
# 59    3
# Name: total_goals, dtype: int64

# %% [markdown]
# ### Taking metrics

# %%
fifa_match_metrics = fifa_df[['attendance', 'total_goals']]

# %%
fifa_match_metrics_sum = fifa_match_metrics.sum()

# %%
fifa_match_metrics_sum
# Out:
# attendance     3113889
# total_goals        158
# dtype: int64

# %%
fifa_match_metrics_sunday_sum = fifa_df[fifa_df['weekday'] == 6][['attendance', 'total_goals']].sum()

# %%
fifa_match_metrics_sunday_sum
# Out:
# attendance     372832
# total_goals        19
# dtype: int64

# %%
fifa_match_metrics.mean()
# Out:
# attendance     51898.150000
# total_goals        2.633333
# dtype: float64

# %% [markdown]
# ### Groupby and aggregations

# %%
fifa_df.groupby('weekday')

# %%
fifa_df.groupby('weekday')[['attendance', 'total_goals']]

# %%
fifa_df.groupby('weekday')[['attendance', 'total_goals']].sum()
# Out:
#          attendance  total_goals
# weekday
# 0            432932           33
# 1            537345           24
# 2            396393           18
# 3            410508           20
# 4            543000           25
# 5            420879           19
# 6            372832           19

# %%
fifa_df.groupby('weekday')[['attendance', 'total_goals']].mean()
# Out:
#            attendance  total_goals
# weekday
# 0        48103.555556     3.666667
# 1        53734.500000     2.400000
# 2        49549.125000     2.250000
# 3        51313.500000     2.500000
# 4        54300.000000     2.500000
# 5        52609.875000     2.375000
# 6        53261.714286     2.714286

# %%
#cumulative sum
fifa_df['cumulative_attendance'] = fifa_df['attendance'].cumsum()

# %%
fifa_df
# Out:
#     match_no day_of_week       date   hour                          venue  \
# 0          1         Sun 2022-11-20  17:00                Al Bayt Stadium
# 1          2         Mon 2022-11-21  14:00  Khalifa International Stadium
# 2          3         Mon 2022-11-21  17:00             Al Thumama Stadium
# 3          4         Mon 2022-11-21  20:00          Ahmed bin Ali Stadium
# 4          5         Tue 2022-11-22  11:00          Lusail Iconic Stadium
# 5          6         Tue 2022-11-22  14:00         Education City Stadium
# 6          7         Tue 2022-11-22  17:00                    Stadium 974
# 7          8         Tue 2022-11-22  20:00              Al Janoub Stadium
# 8          9         Wed 2022-11-23  11:00                Al Bayt Stadium
# 9         10         Wed 2022-11-23  14:00  Khalifa International Stadium
# 10        11         Wed 2022-11-23  17:00             Al Thumama Stadium
# 11        12         Wed 2022-11-23  20:00          Ahmed bin Ali Stadium
# ...

# %% [markdown]
# ### Merging

# %%
#merging 2 dataframes can be done if there is one common column in both dataframes using merge method
#example: merging fifa_df and wine_df on 'quality' column
merged_df = pd.merge(fifa_df, wine_df, on='quality') #if there is quality column in both dataframes
#or
merged_df = wine_df.merge(fifa_df, on='quality')
#or
merged_df = pd.merge(fifa_df, wine_df, left_on='quality', right_on='quality') #if there is no common column name in both dataframes
#or
merged_df = pd.merge(fifa_df, wine_df, left_on='quality', right_on='quality', how='inner') #inner join
#or
merged_df = pd.merge(fifa_df, wine_df, left_on='quality', right_on='quality', how='outer') #outer join
#or
merged_df = pd.merge(fifa_df, wine_df, left_on='quality', right_on='quality', how='left') #left join
#or
merged_df = pd.merge(fifa_df, wine_df, left_on='quality', right_on='quality', how='right') #right join

# %% [markdown]
# ### Writing data back to files

# %%
fifa_results = fifa_df[['1', '2', 'total_goals', 'attendance']]

# %%
fifa_results
# Out:
#                  1               2  total_goals  attendance
# 0            QATAR         ECUADOR            2       67372
# 1          ENGLAND            IRAN            8       45334
# 2          SENEGAL     NETHERLANDS            2       41721
# 3    UNITED STATES           WALES            2       43418
# 4        ARGENTINA    SAUDI ARABIA            3       88012
# 5          DENMARK         TUNISIA            0       42925
# 6           MEXICO          POLAND            0       39369
# 7           FRANCE       AUSTRALIA            5       40875
# 8          MOROCCO         CROATIA            0       59407
# 9          GERMANY           JAPAN            3       42608
# 10           SPAIN      COSTA RICA            7       40013
# 11         BELGIUM          CANADA            1       40432
# 12     SWITZERLAND        CAMEROON            1       39089
# 13         URUGUAY  KOREA REPUBLIC            0       41663
# 14        PORTUGAL           GHANA            5       42662
# ...

# %%
fifa_results.to_csv('./testdata/results/fifa_results.csv', index=False)
#index false or index none will not write the index column to the csv file

# %% [markdown]
# ### Basic plotting with pandas

# %%
fifa_df.attendance.plot()
# Out:
# <AxesSubplot: >

# %%
fifa_df.attendance.plot(kind='hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
fifa_df.set_index('date', inplace=True)

# %%
fifa_df
# Out:
#             match_no day_of_week   hour                          venue  \
# date
# 2022-11-20         1         Sun  17:00                Al Bayt Stadium
# 2022-11-21         2         Mon  14:00  Khalifa International Stadium
# 2022-11-21         3         Mon  17:00             Al Thumama Stadium
# 2022-11-21         4         Mon  20:00          Ahmed bin Ali Stadium
# 2022-11-22         5         Tue  11:00          Lusail Iconic Stadium
# 2022-11-22         6         Tue  14:00         Education City Stadium
# 2022-11-22         7         Tue  17:00                    Stadium 974
# 2022-11-22         8         Tue  20:00              Al Janoub Stadium
# 2022-11-23         9         Wed  11:00                Al Bayt Stadium
# 2022-11-23        10         Wed  14:00  Khalifa International Stadium
# 2022-11-23        11         Wed  17:00             Al Thumama Stadium
# 2022-11-23        12         Wed  20:00          Ahmed bin Ali Stadium
# ...

# %%
fifa_df.set_index('match_no', inplace=True)

# %%
fifa_df
# Out:
#          day_of_week   hour                          venue  \
# match_no
# 1                Sun  17:00                Al Bayt Stadium
# 2                Mon  14:00  Khalifa International Stadium
# 3                Mon  17:00             Al Thumama Stadium
# 4                Mon  20:00          Ahmed bin Ali Stadium
# 5                Tue  11:00          Lusail Iconic Stadium
# 6                Tue  14:00         Education City Stadium
# 7                Tue  17:00                    Stadium 974
# 8                Tue  20:00              Al Janoub Stadium
# 9                Wed  11:00                Al Bayt Stadium
# 10               Wed  14:00  Khalifa International Stadium
# 11               Wed  17:00             Al Thumama Stadium
# 12               Wed  20:00          Ahmed bin Ali Stadium
# 13               Thu  11:00              Al Janoub Stadium
# 14               Thu  14:00         Education City Stadium
# 15               Thu  17:00                    Stadium 974
# ...

# %%
fifa_df['1_goals'].plot()
fifa_df['2_goals'].plot()
# Out:
# <AxesSubplot: xlabel='match_no'>

# %%
team_goal_ratio = fifa_df['1_goals']/fifa_df['2_goals']

# %%
team_goal_ratio.plot(title='Team Goal Ratio')
# Out:
# <AxesSubplot: title={'center': 'Team Goal Ratio'}, xlabel='match_no'>
