# %% [markdown]
# # Python Data Visualization using Matplotlib & Seaborn

# %% [markdown]
# ### Basics

# %% [markdown]
# - Seaborn is built on top of matplotlib to ease certain functions and operations

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
data1 = [0.34, 0.47, 0.43, 0.9, 0.22, 0.73]
plt.plot(data1)

# %%
plt.plot(data1); # ; removes the object output

# %%
farm_yield = [0.34, 0.47, 0.43, 0.9, 0.22, 0.73]
years = [2010, 2011, 2012, 2013, 2014, 2015]
plt.plot(years, farm_yield);

# %% [markdown]
# ### Axis labels

# %%
plt.plot(years, farm_yield);
plt.xlabel('Years')
plt.ylabel('Farming yield')
# Out:
# Text(0, 0.5, 'Farming yield')

# %% [markdown]
# ### Multiple plots

# %%
apples_yield = [0.34, 0.47, 0.43, 0.9, 0.22, 0.73]
oranges_yield = [0.42, 0.93, 0.88, 0.7, 0.78, 0.39]
years = range(2010,2016)
plt.plot(years, apples_yield);
plt.plot(years, oranges_yield);
plt.xlabel('Years')
plt.ylabel('Farming yield')
# Out:
# Text(0, 0.5, 'Farming yield')

# %%
plt.plot(years, apples_yield);
plt.plot(years, oranges_yield);
plt.xlabel('Years')
plt.ylabel('Yields in hectares')
plt.title('Farming yields')
plt.legend(['Apples', 'Oranges'])

# %%
plt.plot(years, apples_yield, marker = 'o');
plt.plot(years, oranges_yield, marker = 'x');
plt.xlabel('Years')
plt.ylabel('Yields in hectares')
plt.title('Farming yields')
plt.legend(['Apples', 'Oranges'])

# %%
plt.plot(years, apples_yield, marker='s', color= 'r', linestyle='-', linewidth=2, markersize=8,markeredgecolor= 'green', markeredgewidth= 2, alpha=0.8);
plt.plot(years, oranges_yield, marker='s', c= 'pink', ls='--', lw=3, ms=10,mec= '#4cff32', mew= 2, alpha=0.6);
plt.xlabel('Years')
plt.ylabel('Yields in hectares')
plt.title('Farming yields')
plt.legend(['Apples', 'Oranges'])

# %% [markdown]
# ### fmt argument

# %%
#fmt argument --> '[marker][linestyle][color]'
plt.plot(years, apples_yield, 'o-b');
plt.plot(years, oranges_yield, 'x--g');
plt.xlabel('Years')
plt.ylabel('Yields in hectares')
plt.title('Farming yields')
plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years, apples_yield, 'ob');

# %%
plt.figure(figsize=(3,3))
plt.plot(years, apples_yield, 'ob');

# %% [markdown]
# ### Style changes using seaborn

# %%
sns.set_style('whitegrid')

# %%
plt.plot(years, apples_yield, 'o-b');
plt.plot(years, oranges_yield, 'x--g');
plt.xlabel('Years')
plt.ylabel('Yields in hectares')
plt.title('Farming yields')
plt.legend(['Apples', 'Oranges']);

# %%
sns.set_style('darkgrid')

# %%
plt.plot(years, apples_yield, 'o-b');
plt.plot(years, oranges_yield, 'x--g');
plt.xlabel('Years')
plt.ylabel('Yields in hectares')
plt.title('Farming yields')
plt.legend(['Apples', 'Oranges']);

# %%
import matplotlib
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9,5)
matplotlib.rcParams['figure.facecolor'] = '#000000'

# %%
plt.plot(years, apples_yield, 'o-b');
plt.plot(years, oranges_yield, 'x--g');
plt.xlabel('Years')
plt.ylabel('Yields in hectares')
plt.title('Farming yields')
plt.legend(['Apples', 'Oranges']);

# %%
print(sns.utils.get_data_home())
#online access to datasets wasn't working so downloaded them manually and placed them on the seaborn home cache folder
# now we can access the local dataset with cache = True
# Out:
# C:\Users\KIIT\AppData\Local\seaborn\seaborn\Cache

# %% [markdown]
# ## Scatterplot

# %%
#seaborn has inbuilt datasets to use just like loading dataframes using pandas
flowers_df = sns.load_dataset('iris', cache=True)

# %%
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.plot(flowers_df.petal_width,flowers_df.petal_length)

# %%
sns.set_style('whitegrid')
sns.scatterplot(flowers_df.petal_width);
sns.scatterplot(flowers_df.petal_length);

# %% [markdown]
# ### Hues and size

# %%
sns.scatterplot(data=flowers_df, x="petal_width", y="petal_length", hue="species", s=70)
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='petal_length'>

# %%
plt.figure(figsize=(12,10))
plt.title('Petal data')
sns.scatterplot(data=flowers_df, x="petal_width", y="petal_length", hue="species", s=70)
# Out:
# <AxesSubplot: title={'center': 'Petal data'}, xlabel='petal_width', ylabel='petal_length'>

# %% [markdown]
# ## Histogram

# %%
plt.title('Petal width distribution')
plt.hist(flowers_df.petal_width)
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Changing size & bin count

# %%
plt.title('Petal width distribution')
plt.hist(flowers_df.petal_width, bins=5)
# Out:
# (array([49.,  8., 41., 29., 23.]),
#  array([0.1 , 0.58, 1.06, 1.54, 2.02, 2.5 ]),
#  <BarContainer object of 5 artists>)

# %%
import numpy as np
plt.title('Petal width distribution')
plt.hist(flowers_df.petal_width, bins=np.arange(0,5,0.5))
# Out:
# (array([48.,  2., 36., 35., 26.,  3.,  0.,  0.,  0.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5]),
#  <BarContainer object of 9 artists>)

# %%
plt.title('Petal width distribution')
plt.hist(flowers_df.petal_width, bins=[1,2,3,4,6])
# Out:
# (array([71., 29.,  0.,  0.]),
#  array([1., 2., 3., 4., 6.]),
#  <BarContainer object of 4 artists>)

# %% [markdown]
# ### Multiple histograms

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
plt.hist(setosa_df.petal_width, bins=np.arange(0,5,0.5), alpha=0.5, label='setosa')
plt.hist(versicolor_df.petal_width, bins=np.arange(0,5,0.5), alpha=0.5, label='versicolor')
plt.legend(['setosa', 'versicolor'])

# %%
plt.title("Petal Width Distribution")

plt.hist([setosa_df.petal_width, versicolor_df.petal_width, virginica_df.petal_width], bins=np.arange(0,5,0.5), alpha=0.5, label=['setosa', 'versicolor', 'virginica'], stacked=True)

plt.legend(['setosa', 'versicolor', 'virginica'])

# %% [markdown]
# ## Bar Chart

# %%
yrs = range(2000, 2010)
apples = [3, 4, 7, 1, 0, 6, 11, 4, 2, 4]
oranges = [5, 6, 2, 1, 0, 3, 2, 1, 1, 1]

# %%
plt.bar(yrs, apples, color='r', label='Apples')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### Bar chart with plot

# %%
plt.bar(yrs, apples, color='b', label='Apples')
plt.plot(yrs, apples, 'o--r')
plt.title('Apples')
# Out:
# Text(0.5, 1.0, 'Apples')

# %% [markdown]
# ### Stacking bar charts

# %%
plt.bar(yrs, apples, color='b', label='Apples')
plt.bar(yrs, oranges, color='orange', label='Oranges', bottom=apples)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ### Bar plots with averages

# %%
tips_df = sns.load_dataset('tips', cache=True)

# %%
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
avg_day_bills = tips_df.groupby('day').total_bill.mean()

# %%
avg_day_bills
# Out:
# day
# Thur    17.682742
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Name: total_bill, dtype: float64

# %%
plt.bar(avg_day_bills.index, avg_day_bills.values)
# Out:
# <BarContainer object of 4 artists>

# %%
sns.barplot(data=tips_df, x='day', y='total_bill')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips_df, x='day', y='total_bill', hue='sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips_df, x='total_bill', y='day')
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# ## Heatmap

# %%
#Heatmap is used for visualization of 2D matrix or table using colors

# %%
flights_df = sns.load_dataset('flights', cache=True)

# %%
flights_df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
plt.plot(flights_df.passengers)

# %%
flights_matrix_df = flights_df.pivot('month', 'year', 'passengers')
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_14224\350297534.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights_matrix_df = flights_df.pivot('month', 'year', 'passengers')

# %%
flights_matrix_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
plt.title('Passengers Heatmap')

sns.heatmap(flights_matrix_df)
# Out:
# <AxesSubplot: title={'center': 'Passengers Heatmap'}, xlabel='year', ylabel='month'>

# %%
plt.title('Passengers Heatmap')
sns.heatmap(flights_matrix_df, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# <AxesSubplot: title={'center': 'Passengers Heatmap'}, xlabel='year', ylabel='month'>

# %% [markdown]
# ## Images

# %%
from urllib.request import urlretrieve
import numpy as np
from PIL import Image

# %%
urlretrieve('https://i.imgur.com/y2XGWkA.jpeg','./testdata/scene.img')
#for some reason, it downloads corrupted image
# Out:
# ('./testdata/scene.img', <http.client.HTTPMessage at 0x1f2df1fc490>)

# %%
img = Image.open('./testdata/kakashi.jpeg')

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=226x127>

# %%
img_array = np.array(img)

# %%
img_array.shape
# Out:
# (127, 226, 3)

# %%
plt.imshow(img_array)

# %%
plt.imshow(img)

# %%
img_array
# Out:
# array([[[  0,  12,  45],
#         [  0,  12,  45],
#         [  0,  12,  45],
#         ...,
#         [ 45, 105, 133],
#         [ 45, 105, 131],
#         [ 40, 100, 126]],
#
#        [[  0,  12,  45],
#         [  0,  13,  46],
#         [  0,  13,  46],
#         ...,
#         [ 48, 109, 138],
#         [ 45, 105, 133],
#         [ 42,  99, 128]],
#
#        [[  0,  13,  48],
#         [  0,  13,  48],
#         [  0,  14,  48],
#         ...,
#         [ 52, 115, 150],
#         [ 51, 107, 140],
#         [ 46, 101, 132]],
#
#        ...,
#
#        [[186, 237, 241],
#         [179, 230, 234],
#         [179, 228, 235],
#         ...,
#         [231, 252, 255],
#         [227, 253, 254],
#         [225, 253, 254]],
#
#        [[188, 239, 243],
#         [181, 232, 236],
#         [173, 222, 229],
#         ...,
#         [231, 252, 255],
#         [227, 253, 254],
#         [225, 253, 254]],
#
#        [[197, 248, 252],
#         [194, 245, 249],
#         [176, 226, 233],
# ...

# %%
plt.grid(False)
plt.axis('off')
plt.imshow(img_array)

# %%
plt.imshow(img_array[0:60,75:150])

# %% [markdown]
# ## Multiple charts

# %%
plt.subplots(2,3)
# Out:
# (<Figure size 900x500 with 6 Axes>,
#  array([[<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >],
#         [<AxesSubplot: >, <AxesSubplot: >, <AxesSubplot: >]], dtype=object))

# %%
plt.subplots(2,3)

plt.tight_layout(pad=2)

# %%
fig, axes = plt.subplots(2,3, figsize = (14,10))

axes[0,0].plot(yrs, apples, 'o--r')
axes[0,0].plot(yrs, oranges, 'o--b')
axes[0,0].set_title('Apples and Oranges')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Number of fruits')
axes[0,0].legend(['Apples', 'Oranges'])

axes[0,1].bar(avg_day_bills.index, avg_day_bills.values)
axes[0,1].set_title('Average Day Bills')

axes[0,2].hist(flowers_df.petal_width, bins=np.arange(0,5,0.5))
axes[0,2].set_title('Petal Width Distribution')

axes[1,0].set_title('Passengers Heatmap')
sns.heatmap(flights_matrix_df, ax=axes[1,0])

axes[1,1].set_title('Kakashi Image')
axes[1,1].grid(False)
axes[1,1].axis('off')
axes[1,1].imshow(img_array)

axes[1,2].set_title('Tips Scatterplot')
sns.scatterplot(data=tips_df, x='total_bill', y='tip', ax=axes[1,2])


plt.tight_layout(pad=2)

# %% [markdown]
# ## KDE Plot

# %%
sns.kdeplot(flowers_df.petal_width)
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='Density'>

# %%
sns.kdeplot(flowers_df.petal_width, fill=True)
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='Density'>

# %%
sns.kdeplot(flowers_df.petal_width, fill=True, thresh=0.5)
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='Density'>
